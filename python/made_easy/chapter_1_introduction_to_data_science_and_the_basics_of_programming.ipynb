# %%
"""Глава 1.

Введение в Data science и основы программирования.
"""

# %% [markdown]
# ### Введение в Data Science
#
# Определения Data Science:
#   - это наука об изучении данных для того, чтобы данные обрели смысл и дали нам полезную информацию.
#   - это научная дисциплина, которая включает в себя извлечение информации из огромных объемов данных с использованием различных научных методов, алгоритмов и процессов.
#   - это междисциплинарная область, которая помогает нам извлекать знания из структурированных или неструктурированных данных.
#
# ### Зачем нам Data Science
#
# 1. Задавать правильные вопросы.
# 2. Находить основную причину проблемы.
# 3. Находить закономерности среди хаотичных необработанных данных.
# 4. Создавать модели для предиктивного анализа.
# 5. Визуализировать и отображать результаты с помощью графиков, информационных панелей и т. д.
# 6. Наделять машины интеллектом.
# 7. Определять лояльность клиентов с помощью анализа настроений.
# 8. Принимать более качественные и быстрые решения.
# 9. Рекомендовать правильный продукт нужному клиенту для развития нашего бизнеса.
#
# ### Настоящее и будущее Data Science
#
#   - Искусственный интеллект.
#   - Машинное обучение.
#   - Глубокое обучение.
#   - Большие данные.
#
# ### Чем занимается специалист по  Data Science
#
# Специалист по анализу данных решает бизнес задачи с помощью следующих шагов:
# 1. Задает правильные вопросы, чтобы понять проблему.
# 2. Собирает данные из нескольких источников.
# 3. Обрабатывает сырые данные и преобразует их в формат, подходящий для анализа.
# 4. Загружает данные в аналитическую систему - алгоритм машинного обучения или статистическая модель.
# 5. Подготавливает результаты и идеи, которые можно изложить заинтересованным сторонам.
#
# ### Предпосылки для Data Science
#
# 1. Программирование
# 2. Статистика
# 3. Базы данных
# 4. Моделирование
#
# ### Профессии в области Data Science
#
#   - Специалист по данным
#   - Дата-инженер
#   - Аналитик данных
#   - Статистик
#   - Администратор данных
#   - Бизнес аналитик
#
# ### Компьютерный алгоритм
#
# Чтобы заставить компьютер сделать что-либо, инструкции должны быть записаны в виде `компьютерной программы`. В ней мы последовательно указываем, что хотим, чтобы компьютер сделал. Помимо того, что нужно сделать компьютеру, мы должны ему сказать как это сделать  - так устроен `компьютерный алгоритм`. В компьютерных системах `алгоритм` - это пример логики, написанной разработчиками программного обеспечения для эффективного выполнения на целевом компьютере и для получения некоторых выходных данных по заданным входным данным. Оптимальный алгоритм дает более быстрые результаты, чем неоптимальный алгоритм для решения той же задачи.
#
# В целом алгоритмы состоят из 3 видов операторов, которые могут присутствовать в различных комбинациях:
# 1. `Последовательные операторы` - выполняются один за другим последовательно.
# 2. `Условные операторы` - когда некоторая часть программы выполняется в зависимости т определенного условия.
# 3. `Циклы или итерации` - набор действий, который в зависимости от определенного условия нужно выполнять снова и снова.
#
#
# ### Блок-схемы
#
# Алгоритм можно изображать в графической форме с использованием определенных обозначений. Полученное изображение называется `блок-схемой`.
#
# ![block-schema](https://i.postimg.cc/X7Hg7czn/photo-2025-02-24-16-47-43.jpg)
#
# ### Что такое язык программирования?
#
# Язык программирования нам нужен, чтобы дать компьютеру какие-то указания. У каждого языка свой синтаксис. Независимо от того, какой язык программирования вы выбрали, компьютер все равно его не понимает. Компьютер понимает совершенно другой язык, который называется `машинным языком`. Но нам было бы сложно писать программы напрямую на машинном языке, потому что он очень сложен и состоит в основном из последовательностей чисел. Именно поэтому приведенные выше языки программирования называются `языками высокого уровня`, т. к. они более похожи на естественные человеческие языки.
#
# ### Что такое исходный код и как его запустить?
#
# Исходный код - это  те самые указания, которые мы даем компьютеру, написанные **неформатированным текстом**. Исходный код пишется в `текстовых редакторах`. Самые простые примеры: блокнот на Windows, TextEdit на MacOS.
#
# Существуют три основных способа перевода исходного кода в машинный код:
# ♦ компиляция;
# ♦ интерпретация;
# ♦ сочетание этих двух способов.
#
# - **Компилятор** - это программа, преобразующая исходный код в машинный. Он переводит или, скорее, компилирует исходный код с языка программирования высокого уровня на машинный язык.
#
# - **Интерпретатор** - это компьютерная программа, которая непосредственно выполняет инструкции, написанные на языке программирования, без предварительной компиляции в программу на машинном языке.
#
# Различия между компиляторами и интерпретаторами:
# 1. Компилятор генерирует автономную программу, написанную на машинном коде, а система интерпретатора выполняет действия, описанные программой высокого уровня.
# 2. После компиляции программы ее исходный код для запуска больше не требуется. У интерпретируемых программ исходный код требуется для запуска программы каждый раз.
# 3. Обычно интерпретируемые программы работают медленнее, чем компилируемые.
#
# Когда мы устанавливаем Python на свой компьютер, интерпретатор идет в комплекте.
#
# ### Что такое IDE?
#
# Для написания компьютерных программ существуют `интегрированные среды разработки` или `IDE` (lntegrated Development Environment). В этих программах есть специальные инструменты, необходимые для написания, отладки и компиляции кода.
#
# **Spider ISE** - это бесплатная научная среда разработки на Python, которая входит в состав дистрибутива Anaconda.
#
#
# ## Упражнения
#
# 1.5.1 Ответы на вопросы:
#
# 1. Какие предметные области входят в Data Science? Что между ними общего и в чем различие?
#
# Программирование, статистика, базы данных, моделирование.
# Общего между ними это то, что все эти области предназначены для обработки большого объема данных в Data Science.
# Различие в том, что все они затрагивают разные области работы с данными: статистика фокусируется на теоретических основах анализа данных, программирование - это практическое применение теоретических знаний для написания программ, базы данных нужны, чтобы хранить данные и извлекать их оттуда, моделирование позволяет выполнять вычисления и прогнозы на основе того, что мы уже знаем о данных.
#
# 2. Как вы понимаете термин «алгоритм»? Как алгоритмы связаны с блок-схемами?
#
# Алгоритм означает последовательность четко определенных шагов или инструкций, которые выполняются для решения определенной задачи или достижения конкретного результата. Блок-схема - это алгоритм графической форме с использованием определенных обозначений.
#
# 3. Какую программу можно назвать хорошей? Запишите все характеристики, какие удастся придумать.
#
#  * Функциональность
#  * Удобство использования
#  * Производительность
#  * Надежность
#  * Безопасность
#  * Совместимость
#  * Масштабируемость
#  * Качество кода
#  * Документация
#  * Поддержка и обновление
#  * Простота установки и настройки
#
# 4. Какой язык понимает компьютер?
#
# Машинный
#
# 5. Чем языки программирования отличаются от языков, на которых мы говорим?
#
# Инструкции в программе мы можем написать только на специализированном языке программирования, которые будут понятны компилятору и/или интерпретатору.
#
# 1.5.2 Правда или ложь
#
# 1. Машинное обучение -это инструмент для извлечения знаний из данных - Правда.
# 2. Глубокое обучение - это то же самое, что машинное обучение - Ложь.
# 3. Все инженеры-программисты также могут считаться специалистами по данным - Ложь.
# 4. Статистика- важный инструмент для специалистов по данным - Правда.
# 5. Компьютер может принимать решения, выходящие за рамки данных ему инструкций, подстраиваясь под изменения среды - Ложь.
# 6. Компьютеры понимают языки программирования «как есть» - Ложь.
# 7. Некоторые языки программирования компилируются, некоторые интерпретируются, а некоторые используют и то и другое - Правда.
# 8. Все программы выполняются последовательно - Ложь.
# 9. В IDE есть встроенный текстовый редактор - Правда.
# 10. Компиляторы и интерпретаторы - это такие механизмы, наподобие привода для компакт-дисков - Ложь.
#
# 1.5.3 Практические задания
#
# 1. Напишите алгоритм для расчета простых процентов от некоторой суммы.
#
#   1) Начало
#   2) Сумму записываем в переменную $ \textit{SUM} $
#   3) Запросить процент, который мы хотим рассчитать, у пользователя, делим его на 100 и записываем в переменную $ \textit{PERCENT} $
#   4) Умножаем $ \textit{SUM} $ на $ \textit{PERCENT} $
#   5) Конец
#
# 2. Напишите алгоритм для вычисления площади прямоугольника.
#
#   1) Начало
#   2) Запросить у пользователя длину и ширину прямоугольника и запишем их в переменные $ \textit{LENGTH} $ и $ \textit{WIDTH} $
#   3) Добавляем проверку на то, что $ \textit{LENGTH} $ и $ \textit{WIDTH} $ > 0 - если так, то переходим к шагу 4, иначе к шагу 6
#   4) Умножаем $ \textit{LENGTH} $ и $ \textit{WIDTH} $ и записываем результат в переменную $ \textit{S} $
#   5) Выводим переменную $ \textit{S} $
#   6) Вывод сообщения об ошибке, что $ \textit{LENGTH} $ и/или $ \textit{WIDTH} $ < 0
#   7) Конец
#
# 3. Напишите алгоритм вычисления периметра круга.
#
#   1) Начало
#   2) Запрашиваем у пользователя радиус круга и записываем его в переменную $ \textit{RADIUS} $
#   3) Добавляем проверку на то, что $ \textit{RADIUS} $ > 0 - если так, то переходим к шагу 4, иначе к к шагу 6
#   4) Умножаем $ \textit{RADIUS} $ на $2\pi$ и записываем результат в переменную $ \textit{P} $
#   5) Выводим переменную $ \textit{P} $
#   6) Вывод сообщения об ошибке, что $ \textit{RADIUS} $ < 0
#   7) Конец
#
# 4. Напишите алгоритм, который находит все простые числа меньше 100.
#
#   1) Начало
#   2) Инициализация списка $ \textit{NUMBERS} $ от 2 до 99
#   3) В цикле $ \textit{i} $ от 2 до квадратного корня из 100 (т.е. до 10) вычеркнуть все кратные числа $ \textit{i} $ (начиная с $ i^2 $) так как они не являются простыми
#   4) Вывести все оставшиеся невычеркнутые числа - они являются простыми
#   5) Конец
#
# 5. Напишите алгоритм превращения предложения, написанного в верхнем регистре, в обычный для предложений регистр.
#
#   1) Начало
#   2) Записать предложение, написанное в верхнем регистре в переменную $ \textit{STRING} $
#   3) Перевести все предложение в нижний регистр
#   4) Вернуть верхний регистр первой букве
#   5) Вывести переменную $ \textit{STRING} $
#   6) Конец
#
# 6. Составьте блок-схему приготовления льда из кипяченой воды с помощью холодильника.
#
# ![ice_schema](https://i.postimg.cc/htFrrg7z/photo-2025-02-25-09-38-10.jpg)
#
# 7. Составьте блок-схему для нахождения суммы всех четных чисел меньше ста.
#
# ![sum](https://i.postimg.cc/RZFCW2vW/photo-2025-02-25-09-55-20.jpg)
#
# 8. Составьте блок-схему для вычисления квадрата всех нечетных чисел от 1 до 15 включительно.
#
# ![squares](https://i.postimg.cc/XJ87GWBy/photo-2025-02-25-10-15-38.jpg)
#
# 9. Составьте блок-схему вывода таблицы умножения на 3.
#
# ![mul](https://i.postimg.cc/qMv7qzbv/photo-2025-02-25-10-42-40.jpg)
#
# 10. Составьте блок-схему для расчета сложных процентов (с капитализацией).
#
# ![capitalization](https://i.postimg.cc/vm5y3VHM/photo-2025-02-25-10-56-54.jpg)
